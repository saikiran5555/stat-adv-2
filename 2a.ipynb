# %% [markdown]
# The Cumulative Density Function (CDF) is an important concept in statistics and probability theory. It describes the probability that a real-valued random variable
# �
# X with a given probability distribution will be found at a value less than or equal to
# �
# x. Essentially, the CDF gives the cumulative probability associated with a distribution up to a certain value.
#
# Definition of CDF
# For a random variable
# �
# X, the Cumulative Density Function
# �
# (
# �
# )
# F(x) is defined as:
#
# �
# (
# �
# )
# =
# �
# (
# �
# ≤
# �
# )
# F(x)=P(X≤x)
#
# This means that
# �
# (
# �
# )
# F(x) represents the probability that the random variable
# �
# X takes on a value less than or equal to
# �
# x.
#
# Example
# Suppose we have a random variable
# �
# X that follows a normal distribution with a mean (
# �
# μ) of 0 and a standard deviation (
# �
# σ) of 1 (a standard normal distribution). The CDF at
# �
# =
# 1
# x=1 would be the probability that
# �
# X is less than or equal to 1. Mathematically, this is represented as:
#
# �
# (
# 1
# )
# =
# �
# (
# �
# ≤
# 1
# )
# F(1)=P(X≤1)
#
# In a standard normal distribution, this would roughly be 0.8413, meaning there's an 84.13% chance that a value drawn from this distribution is less than or equal to 1.
#
# Why CDF is Used
# Understanding Distributions: The CDF provides a comprehensive view of the probability distribution of a random variable. It helps in understanding the spread and the central tendency of the data.
#
# Probability Calculations: It is useful for calculating the probability that the variable takes a value within a certain range. For instance,
# �
# (
# �
# <
# �
# ≤
# �
# )
# =
# �
# (
# �
# )
# −
# �
# (
# �
# )
# P(a<X≤b)=F(b)−F(a).
#
# Non-parametric Analysis: CDFs are not tied to any specific type of distribution (like normal, binomial, etc.). Thus, they are useful in analyzing data sets that don't necessarily follow a known distribution.
#
# Comparison of Distributions: CDFs can be used to compare the underlying distributions of different data sets. This is particularly useful in fields like statistical hypothesis testing.
#
# Real-World Applications: In practice, CDFs are used in various fields such as finance (for risk assessment), meteorology (for precipitation probabilities), engineering (for failure rates), and many others.
#
# In summary, the Cumulative Density Function is a fundamental tool in probability and statistics, providing detailed insights into the behavior of random variables and forming the basis for various analytical and practical applications.
