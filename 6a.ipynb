# %% [markdown]
# To find the probability that a randomly selected observation is greater than 60 in a normally distributed dataset with a mean (μ) of 50 and a standard deviation (σ) of 10, you can use the Z-score formula to standardize the value, and then use the standard normal distribution to find the probability.
#
# Step 1: Calculate the Z-score
# The Z-score of a value in a distribution is given by the formula:
#
# �
# =
# (
# �
# −
# �
# )
# �
# Z=
# σ
# (X−μ)
# ​
#
#
# Where
# �
# X is the value of interest,
# �
# μ is the mean, and
# �
# σ is the standard deviation. For
# �
# =
# 60
# X=60:
#
# �
# =
# (
# 60
# −
# 50
# )
# 10
# =
# 10
# 10
# =
# 1
# Z=
# 10
# (60−50)
# ​
#  =
# 10
# 10
# ​
#  =1
#
# Step 2: Use the Standard Normal Distribution
# A Z-score of 1 corresponds to a value one standard deviation above the mean in a standard normal distribution. We need to find the probability that a value is greater than this.
#
# In standard normal distribution tables, the values given are the probabilities that a value is less than the Z-score. For a Z-score of 1, this probability is approximately 0.8413. However, we want the probability that a value is greater than this Z-score.
#
# Step 3: Calculate the Probability
# Since the total probability of any event in a probability distribution is 1, the probability that a value is greater than a Z-score of 1 is:
#
# �
# (
# �
# >
# 60
# )
# =
# 1
# −
# �
# (
# �
# ≤
# 60
# )
# P(X>60)=1−P(X≤60)
# �
# (
# �
# >
# 60
# )
# =
# 1
# −
# 0.8413
# =
# 0.1587
# P(X>60)=1−0.8413=0.1587
#
# Therefore, the probability that a randomly selected observation from this dataset is greater than 60 is approximately 0.1587, or 15.87%.
